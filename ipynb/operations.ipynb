# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import phuzzy as ph
from phuzzy.mpl import mix_mpl

# %%
x = ph.Trapezoid(alpha0=[-1, 2], alpha1=[0.5, 1.8], number_of_alpha_levels=15)
mix_mpl(x)
x.plot()
x
# Out:
# Trapezoid(x:[[-1.0, 2.0], [0.5, 1.8]])

# %%
y = x * x
mix_mpl(y)
y.plot()
y
# Out:
# Trapezoid(x*x:[[-2.0, 4.0], [0.25, 3.24]])

# %%
y = x ** 2
mix_mpl(y)
y.plot()
y
# Out:
# FuzzyNumber(x^2:[[0.0, 4.0], [0.25, 3.24]])

# %%
y = x ** .5
mix_mpl(y)
y.plot()
y.df
# Out:
#        alpha         l         r
# 0   0.000000  0.000000  1.414214
# 1   0.071429  0.000000  1.409154
# 2   0.142857  0.000000  1.404076
# 3   0.214286  0.000000  1.398979
# 4   0.285714  0.000000  1.393864
# 5   0.357143  0.000000  1.388730
# 6   0.428571  0.000000  1.383577
# 7   0.500000  0.000000  1.378405
# 8   0.571429  0.000000  1.373213
# 9   0.642857  0.000000  1.368002
# 10  0.714286  0.267261  1.362770
# 11  0.785714  0.422577  1.357519
# 12  0.857143  0.534522  1.352247
# 13  0.928571  0.626783  1.346954
# 14  1.000000  0.707107  1.341641

# %%
y = abs(x)
mix_mpl(y)
y.plot()
y.df
# Out:
#        alpha         l         r
# 0   0.000000  0.000000  2.000000
# 1   0.071429  0.000000  1.985714
# 2   0.142857  0.000000  1.971429
# 3   0.214286  0.000000  1.957143
# 4   0.285714  0.000000  1.942857
# 5   0.357143  0.000000  1.928571
# 6   0.428571  0.000000  1.914286
# 7   0.500000  0.000000  1.900000
# 8   0.571429  0.000000  1.885714
# 9   0.642857  0.000000  1.871429
# 10  0.714286  0.071429  1.857143
# 11  0.785714  0.178571  1.842857
# 12  0.857143  0.285714  1.828571
# 13  0.928571  0.392857  1.814286
# 14  1.000000  0.500000  1.800000

# %%
x.convert_df(5)
y = -x
mix_mpl(y)
y.plot()
y.df
# Out:
#    alpha     l      r
# 0   0.00 -2.00  1.000
# 1   0.25 -1.95  0.625
# 2   0.50 -1.90  0.250
# 3   0.75 -1.85 -0.125
# 4   1.00 -1.80 -0.500

# %%
y = x - 3
mix_mpl(y)
y.plot()
y.df
# Out:
#    alpha      l     r
# 0   0.00 -4.000 -1.00
# 1   0.25 -3.625 -1.05
# 2   0.50 -3.250 -1.10
# 3   0.75 -2.875 -1.15
# 4   1.00 -2.500 -1.20

# %%
y = x / 2
mix_mpl(y)
y.plot()
y.df
# Out:
#    alpha       l      r
# 0   0.00 -0.5000  1.000
# 1   0.25 -0.3125  0.975
# 2   0.50 -0.1250  0.950
# 3   0.75  0.0625  0.925
# 4   1.00  0.2500  0.900

# %%
y = x ** 0
mix_mpl(y)
y.plot()
y.df
# Out:
#    alpha    l    r
# 0   0.00  1.0  1.0
# 1   0.25  1.0  1.0
# 2   0.50  1.0  1.0
# 3   0.75  1.0  1.0
# 4   1.00  1.0  1.0

# %%
y = 0 ** x
mix_mpl(y)
y.plot()
y.df
# Out:
#    alpha    l    r
# 0   0.00  0.0  0.0
# 1   0.25  0.0  0.0
# 2   0.50  0.0  0.0
# 3   0.75  0.0  0.0
# 4   1.00  0.0  0.0
